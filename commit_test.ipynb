# %%
# korbi test commit

print("Hello world")
print("This is a test commit for Korbi")
print("I hope this works correctly")
print("Goodbye world")
# Out:
# Hello world
# This is a test commit for Korbi
# I hope this works correctly
# Goodbye world

# %%
print("Test Oce")
print("Test Oce 2")
# Out:
# Test Oce
# Test Oce 2

# %%
print("i got a new email")
# Out:
# i got a new email
